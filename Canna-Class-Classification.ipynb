# %% [markdown]
# ## Necessary Imports

# %%
from bs4 import BeautifulSoup
from collections import Counter
from imblearn.over_sampling import SMOTE 
from matplotlib_venn import venn2
from scipy import stats
from sklearn import tree, svm
from sklearn.decomposition import PCA
from sklearn.dummy import DummyClassifier
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier, AdaBoostClassifier
from sklearn.externals.six import StringIO 
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import precision_score, recall_score, accuracy_score 
from sklearn.metrics import auc, confusion_matrix, f1_score, roc_curve
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler, label_binarize
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from tqdm import tqdm_notebook as tqdm

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import re
import requests
import seaborn as sns
import warnings

# %% [markdown]
# # WikiLeaf Scraping

# %%
# webscrape 2249 strains from WikiLeaf using BeautifulSoup

# create empty lists for storing the data
names,races=[],[]

# scrape data from all 71 pages of WikiLeaf
for i in tqdm(range(1,72)):
    response=requests.get('https://www.wikileaf.com/strains/?page={}'.format(i))
    soup=BeautifulSoup(response.content,'html.parser')
    
    # use corresponding tags for names and races
    name=soup.findAll('h5',{'class':'name disp-title'})
    race=soup.findAll('p',{'class':'tag'})
   
    
    for n,r in zip(name,race):
        names.append(n.text)
        races.append(r.text)
# Out:
# HBox(children=(IntProgress(value=0, max=71), HTML(value='')))

# %%
# scrape the urls for each strain

links = []
for i in tqdm(range(1,72)):
    response=requests.get('https://www.wikileaf.com/strains/?page={}'.format(i))
    soup=BeautifulSoup(response.content,'html.parser')
    
    for b in soup.find_all('a',href=True):
        # eliminate duplicate entries 
        if b.get_attribute_list('href') not in links:
            links.append(b.get_attribute_list('href'))
# Out:
# HBox(children=(IntProgress(value=0, max=71), HTML(value='')))

# %%
# append links for singular strain to list

strain_links = []

for lin in links:
    for l in lin:
        if '/strain/' in l:
            strain_links.append('https://www.wikileaf.com'+l)

# %%
# scrape effects and usage data from each individual strain

for i in tqdm(strain_links):
    response=requests.get(i)
    soup=BeautifulSoup(response.content,'html.parser')
    
    for b in soup.find_all('div',{'class':'effect-label'}):
        print(b.contents)
# Out:
# HBox(children=(IntProgress(value=0, max=2249), HTML(value='')))
# ['Relaxed']
# ['Sleepy']
# ['Cotton Mouth']
# ['Depressed']
# ['A Loss of Appetite']
# ['Anxiety']
# ['Focused']
# ['Paranoia']
# ['Creative']
# ['Depressed']
# ['A Loss of Appetite']
# ['Anxiety']
# ['Paranoia']
# ['Cotton Mouth']
# ['Creative']
# ['Depressed']
# ['A Loss of Appetite']
# ['Anxiety']
# ['Paranoia']
# ['Cotton Mouth']
# ['Creative']
# ['Depressed']
# ['A Loss of Appetite']
# ['Anxiety']
# ['Paranoia']
# ['Cotton Mouth']
# ['Creative']
# ['Depressed']
# ['A Loss of Appetite']
# ['Anxiety']
# ['Focused']
# ['Cotton Mouth']
# ['Creative']
# ['Depressed']
# ['A Loss of Appetite']
# ['Pain']
# ['Relaxed']
# ['Cotton Mouth']
# ['Creative']
# ['Depressed']
# ['A Loss of Appetite']
# ['Anxiety']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-151-cd07f8759b3a> in <module>
#       2
#       3 for i in tqdm(strain_links):
# ----> 4     response=requests.get(i)
#       5     soup=BeautifulSoup(response.content,'html.parser')
#       6
#
# ~/anaconda3/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~/anaconda3/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# ~/anaconda3/lib/python3.7/http/client.py in getresponse(self)
#    1319         try:
#    1320             try:
# -> 1321                 response.begin()
#    1322             except ConnectionError:
#    1323                 self.close()
#
# ~/anaconda3/lib/python3.7/http/client.py in begin(self)
#     294         # read until we get a non-100 response
#     295         while True:
# --> 296             version, status, reason = self._read_status()
#     297             if status != CONTINUE:
#     298                 break
#
# ~/anaconda3/lib/python3.7/http/client.py in _read_status(self)
#     255
#     256     def _read_status(self):
# --> 257         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     258         if len(line) > _MAXLINE:
#     259             raise LineTooLong("status line")
#
# ~/anaconda3/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     295     def recv_into(self, *args, **kwargs):
#     296         try:
# --> 297             return self.connection.recv_into(*args, **kwargs)
#     298         except OpenSSL.SSL.SysCallError as e:
#     299             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# ~/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1819             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1820         else:
# -> 1821             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1822         self._raise_ssl_error(self._ssl, result)
#    1823
#
# KeyboardInterrupt:

# %%
# scrape THC content data from each individual strain page

contents = []
for i in tqdm(strain_links):
    response=requests.get(i)
    soup=BeautifulSoup(response.content,'html.parser')
    
    for b in soup.find_all('small'):
        if '%' in b.text:
            contents.append(b.text)
# Out:
# HBox(children=(IntProgress(value=0, max=2249), HTML(value='')))

# %%
# slice contents list into sublists of 5 values
# each strain has 5 thc values associated to it:
# highest test, strain avg., race avg., wikileaf avg., wikileaf highest

strain_contents = [contents[i:i+5] for i in tqdm(range(0, len(contents), 5))]
# Out:
# HBox(children=(IntProgress(value=0, max=2249), HTML(value='')))

# %%
# turn strain contents to dataframe

df = pd.DataFrame(strain_contents,columns=['thc_content','strain_avg','race_avg','wikileaf_avg','wikileaf_high'])
df.head()
# Out:
#   thc_content strain_avg race_avg wikileaf_avg wikileaf_high
# 0         20%        17%    12.5%          18%           35%
# 1         22%      18.5%    13.5%          18%           35%
# 2         24%      20.5%    13.5%          18%           35%
# 3         17%      15.5%    13.5%          18%           35%
# 4         17%        15%    13.5%          18%           35%

# %% [markdown]
# # Leafly Scraping

# %%
# https://www.leafly.com/strains?sort=name&page=1
    
# webscrape 114 pages from Leafly using BeautifulSoup

# create empty lists for storing the data
names1 = []

# scrape data from all 114 pages of WikiLeaf
for i in tqdm(range(1,115)):
    response=requests.get('https://www.leafly.com/strains?sort=name&page={}'.format(i))
    soup=BeautifulSoup(response.content,'html.parser')
    
    # use corresponding tags for names and races
    name=soup.findAll('div',{'class':'strain-tile__name'})
    
    for n in name:
        names1.append(n.text)
# Out:
# HBox(children=(IntProgress(value=0, max=114), HTML(value='')))

# %%
# scrape the urls for each strain

links1 = []
for i in tqdm(range(1,115)):
    response=requests.get('https://www.leafly.com/strains?sort=name&page={}'.format(i))
    soup=BeautifulSoup(response.content,'html.parser')
    
    for b in soup.find_all('a',href=True):
        # eliminate duplicate entries 
        if b.get_attribute_list('href') not in links:
            links1.append(b.get_attribute_list('href'))
# Out:
# HBox(children=(IntProgress(value=0, max=114), HTML(value='')))

# %%
# filter for 3411 urls for singular strains

strain_links2 = []
for lin in links1:
    for l in lin:
        if '/strains/' in l 
            strain_links2.append('https://www.leafly.com'+l)

# %%
# scrape THC content data from each individual strain page

contents = []
for i in tqdm(strain_links2):
    response=requests.get(i)
    soup=BeautifulSoup(response.content,'html.parser')
    
    for b in soup.find_all('small'):
        if '%' in b.text:
            contents.append(b.text)

# %% [markdown]
# # CannaConnection Scraping

# %%
import string
abc0 = list(string.ascii_lowercase)

# %%
# https://www.cannaconnection.com/strains?show_char=a
    
# webscrape all pages from CannaConnection using BeautifulSoup

# create empty lists for storing the data
names2 = []

# scrape data from all 114 pages of WikiLeaf
for i in tqdm(abc0):
    response=requests.get('https://www.cannaconnection.com/strains?show_char={}'.format(i))
    soup=BeautifulSoup(response.content,'html.parser')
    
    # use corresponding tags for names and races
    name=soup.findAll('ul',{'class':'strains-list'})
    
    for n in name:
        names2.append(n.text.split('\n'))
# Out:
# HBox(children=(IntProgress(value=0, max=26), HTML(value='')))

# %%
len(names2)
# Out:
# 26

# %%
all_names = []
for names in names2:
    for n in names:
        if len(n) > 2:
            all_names.append(n)

# %%
# scrape the urls for each strain

links3 = []
for i in tqdm(abc0):
    response=requests.get('https://www.cannaconnection.com/strains?show_char={}'.format(i))
    soup=BeautifulSoup(response.content,'html.parser')
    
    for b in soup.find_all('a',href=True):
        # eliminate duplicate entries 
        if b.get_attribute_list('href') not in links3:
            links3.append(b.get_attribute_list('href'))
# Out:
# HBox(children=(IntProgress(value=0, max=26), HTML(value='')))

# %%
links3
# Out:
# [['https://www.cannaconnection.com/'],
#  ['/strains'],
#  ['https://www.cannaconnection.com/strains'],
#  ['https://www.cannaconnection.com/strains?show_char=a'],
#  ['https://www.cannaconnection.com/strains?show_char=b'],
#  ['https://www.cannaconnection.com/strains?show_char=c'],
#  ['https://www.cannaconnection.com/strains?show_char=d'],
#  ['https://www.cannaconnection.com/strains?show_char=e'],
#  ['https://www.cannaconnection.com/strains?show_char=f'],
#  ['https://www.cannaconnection.com/strains?show_char=g'],
#  ['https://www.cannaconnection.com/strains?show_char=h'],
#  ['https://www.cannaconnection.com/strains?show_char=i'],
#  ['https://www.cannaconnection.com/strains?show_char=j'],
#  ['https://www.cannaconnection.com/strains?show_char=k'],
#  ['https://www.cannaconnection.com/strains?show_char=l'],
#  ['https://www.cannaconnection.com/strains?show_char=m'],
#  ['https://www.cannaconnection.com/strains?show_char=n'],
#  ['https://www.cannaconnection.com/strains?show_char=o'],
#  ['https://www.cannaconnection.com/strains?show_char=p'],
#  ['https://www.cannaconnection.com/strains?show_char=q'],
#  ['https://www.cannaconnection.com/strains?show_char=r'],
#  ['https://www.cannaconnection.com/strains?show_char=s'],
#  ['https://www.cannaconnection.com/strains?show_char=t'],
#  ['https://www.cannaconnection.com/strains?show_char=u'],
#  ['https://www.cannaconnection.com/strains?show_char=v'],
#  ['https://www.cannaconnection.com/strains?show_char=w'],
#  ['https://www.cannaconnection.com/strains?show_char=x'],
#  ['https://www.cannaconnection.com/strains?show_char=y'],
#  ['https://www.cannaconnection.com/strains?show_char=z'],
#  ['https://www.cannaconnection.com/strains?show_char=0-9'],
#  ['/hall-of-fame'],
#  ['/strains-top-10-lists'],
#  ['/strains/breeders'],
#  ['/grow-reports'],
#  ['/strainfinder'],
#  ['https://www.cannaconnection.com/strains/super-silver-haze'],
#  ['/blog/category/grow'],
#  ['/blog/category/grow-basics'],
#  ['/blog/category/grow-advanced'],
#  ['/blog/category/grow-troubleshooting'],
#  ['/grow-reports'],
#  ['/blog/category/grow-various'],
#  ['/blog/871-top-10-mistakes-beginning-grower'],
#  ['https://www.cannaconnection.com/blog/19222-global-cannabis-legality-and-regulation-how-is-it-managed'],
#  ['https://www.cannaconnection.com/blog/19222-global-cannabis-legality-and-regulation-how-is-it-managed'],
#  ['https://www.cannaconnection.com/blog/1913-how-to-germinate-seeds'],
#  ['https://www.cannaconnection.com/blog/1913-how-to-germinate-seeds'],
#  ['/blog/category/articles'],
#  ['/blog/category/smoking'],
#  ['/blog/category/vaping'],
#  ['/blog/category/dabbing'],
#  ['/blog/category/edibles'],
#  ['/blog/category/concentrates'],
#  ['/blog/category/reviews'],
#  ['/blog/category/use-101-various'],
#  ['https://www.cannaconnection.com/blog/8715-new-law-in-canada-legalisation-or-prohibition-2-0'],
#  ['https://www.cannaconnection.com/blog/8715-new-law-in-canada-legalisation-or-prohibition-2-0'],
#  ['https://www.cannaconnection.com/blog/18236-cannabis-gummy-bear-recipe'],
#  ['https://www.cannaconnection.com/blog/18236-cannabis-gummy-bear-recipe'],
#  ['/blog/category/culture'],
#  ['/blog/category/how-to'],
#  ['/blog/category/music-movies'],
#  ['/blog/category/reviews'],
#  ['/blog/category/marijuana-vips'],
#  ['/blog/category/organizations'],
#  ['/blog/category/various-culture'],
#  ['https://www.cannaconnection.com/stocks'],
#  ['https://www.cannaconnection.com/blog/8715-new-law-in-canada-legalisation-or-prohibition-2-0'],
#  ['https://www.cannaconnection.com/blog/8715-new-law-in-canada-legalisation-or-prohibition-2-0'],
#  ['https://www.cannaconnection.com/blog/18236-cannabis-gummy-bear-recipe'],
#  ['https://www.cannaconnection.com/blog/18236-cannabis-gummy-bear-recipe'],
#  ['/shop'],
#  ['/strains'],
#  ['/blog/category/grow'],
#  ['/blog/category/articles'],
#  ['/blog/category/culture'],
#  ['/shop'],
#  ['/strains'],
#  ['https://www.cannaconnection.com/strains'],
#  ['/hall-of-fame'],
#  ['/strains-top-10-lists'],
#  ['/strains/breeders'],
#  ['/grow-reports'],
#  ['/strainfinder'],
#  ['/blog/category/grow'],
#  ['/blog/category/grow-basics'],
#  ['/blog/category/grow-advanced'],
#  ['/blog/category/grow-troubleshooting'],
#  ['/grow-reports'],
#  ['/blog/category/grow-various'],
#  ['/blog/871-top-10-mistakes-beginning-grower'],
#  ['/blog/category/articles'],
#  ['/blog/category/smoking'],
#  ['/blog/category/vaping'],
#  ['/blog/category/dabbing'],
#  ['/blog/category/edibles'],
#  ['/blog/category/concentrates'],
#  ['/blog/category/reviews'],
#  ['/blog/category/use-101-various'],
#  ['/blog/category/culture'],
#  ['/blog/category/how-to'],
#  ['/blog/category/music-movies'],
#  ['/blog/category/reviews'],
#  ['/blog/category/marijuana-vips'],
#  ['/blog/category/organizations'],
#  ['/blog/category/various-culture'],
#  ['https://www.cannaconnection.com/stocks'],
#  ['/shop'],
#  ['https://www.cannaconnection.com/'],
#  ['https://www.facebook.com/Cannabisinfo-1324180974316509/?fref=ts'],
#  ['https://www.instagram.com/cannaconnection420/'],
#  ['https://www.cannaconnection.fr/varietes?SID=kf31sjq1ktqmlstqttj67dpnu2'],
#  ['https://www.cannaconnection.es/variedades?SID=kf31sjq1ktqmlstqttj67dpnu2'],
#  ['https://www.cannaconnection.de/sorten?SID=kf31sjq1ktqmlstqttj67dpnu2'],
#  ['https://www.cannaconnection.it/varieta?SID=kf31sjq1ktqmlstqttj67dpnu2'],
#  ['https://www.cannaconnection.com/login'],
#  ['https://www.cannaconnection.com/login?type=business'],
#  ['https://www.cannaconnection.com/home/about-us'],
#  ['https://www.cannaconnection.com/home/promote-your-shop'],
#  ['https://www.cannaconnection.com/home/advertise-with-us'],
#  ['/en/strains'],
#  ['/en/blog/category/grow'],
#  ['/en/blog/category/articles'],
#  ['/en/blog/category/culture'],
#  ['/home/privacy-policy'],
#  ['https://www.cannaconnection.com/home/cookies-policy'],
#  ['/home/terms-and-conditions'],
#  ['/sitemap'],
#  ['https://www.cannaconnection.fr/varietes?SID=kf31sjq1ktqmlstqttj67dpnu2'],
#  ['https://www.cannaconnection.es/variedades?SID=kf31sjq1ktqmlstqttj67dpnu2'],
#  ['https://www.cannaconnection.de/sorten?SID=kf31sjq1ktqmlstqttj67dpnu2'],
#  ['https://www.cannaconnection.it/varieta?SID=kf31sjq1ktqmlstqttj67dpnu2'],
#  ['https://www.cannaconnection.com/login'],
#  ['https://www.cannaconnection.com/login?type=business'],
#  ['https://www.cannaconnection.com/blog/category/grow'],
#  ['https://www.cannaconnection.com/blog/category/articles'],
#  ['https://www.cannaconnection.com/blog/category/culture'],
#  ['https://www.cibdol.com/cbd-deals'],
#  ['https://www.zamnesia.com/zamnesia-seeds/6000-runtz-feminized.html'],
#  ['https://www.royalqueenseeds.com'],
#  ['https://www.bitcanna.io'],
#  ['https://www.facebook.com/Cannabisinfo-1324180974316509/?fref=ts'],
#  ['https://www.instagram.com/cannaconnection420/'],
#  ['https://www.cannaconnection.com/'],
#  ['https://www.cannaconnection.com/strains'],
#  ['https://www.cannaconnection.com/hall-of-fame'],
#  ['https://www.cannaconnection.com/strains-top-10-lists'],
#  ['https://www.cannaconnection.com/strains/breeders'],
#  ['https://www.cannaconnection.com/strainfinder'],
#  ['https://www.cannaconnection.com/strains?show_char=a'],
#  ['https://www.cannaconnection.com/strains?show_char=b'],
#  ['https://www.cannaconnection.com/strains?show_char=c'],
#  ['https://www.cannaconnection.com/strains?show_char=d'],
#  ['https://www.cannaconnection.com/strains?show_char=e'],
#  ['https://www.cannaconnection.com/strains?show_char=f'],
#  ['https://www.cannaconnection.com/strains?show_char=g'],
#  ['https://www.cannaconnection.com/strains?show_char=h'],
#  ['https://www.cannaconnection.com/strains?show_char=i'],
#  ['https://www.cannaconnection.com/strains?show_char=j'],
#  ['https://www.cannaconnection.com/strains?show_char=k'],
#  ['https://www.cannaconnection.com/strains?show_char=l'],
#  ['https://www.cannaconnection.com/strains?show_char=m'],
#  ['https://www.cannaconnection.com/strains?show_char=n'],
#  ['https://www.cannaconnection.com/strains?show_char=o'],
#  ['https://www.cannaconnection.com/strains?show_char=p'],
#  ['https://www.cannaconnection.com/strains?show_char=q'],
#  ['https://www.cannaconnection.com/strains?show_char=r'],
#  ['https://www.cannaconnection.com/strains?show_char=s'],
#  ['https://www.cannaconnection.com/strains?show_char=t'],
#  ['https://www.cannaconnection.com/strains?show_char=u'],
#  ['https://www.cannaconnection.com/strains?show_char=v'],
#  ['https://www.cannaconnection.com/strains?show_char=w'],
#  ['https://www.cannaconnection.com/strains?show_char=x'],
#  ['https://www.cannaconnection.com/strains?show_char=y'],
#  ['https://www.cannaconnection.com/strains?show_char=z'],
#  ['https://www.cannaconnection.com/strains?show_char=0-9'],
#  ['https://www.cannaconnection.com/strains/ac-diesel'],
#  ['https://www.cannaconnection.com/strains/a-m-s'],
#  ['https://www.cannaconnection.com/strains/a-1-haze'],
#  ['https://www.cannaconnection.com/strains/acapulco-gold'],
#  ['https://www.cannaconnection.com/strains/acdc'],
#  ['https://www.cannaconnection.com/strains/ace-silver-haze'],
#  ['https://www.cannaconnection.com/strains/acid'],
#  ['https://www.cannaconnection.com/strains/afghan-hash-plant'],
#  ['https://www.cannaconnection.com/strains/afghan-haze'],
#  ['https://www.cannaconnection.com/strains/afghan-kush'],
#  ['https://www.cannaconnection.com/strains/afghan-kush-ryder'],
#  ['https://www.cannaconnection.com/strains/afghan-og'],
#  ['https://www.cannaconnection.com/strains/afghan-skunk'],
#  ['https://www.cannaconnection.com/strains/afghani'],
#  ['https://www.cannaconnection.com/strains/afghani-1-autoflowering'],
#  ['https://www.cannaconnection.com/strains/afghani-gold'],
#  ['https://www.cannaconnection.com/strains/afgooey'],
#  ['https://www.cannaconnection.com/strains/afrodite'],
#  ['https://www.cannaconnection.com/strains/agent-orange'],
#  ['https://www.cannaconnection.com/strains/airborne-genius'],
#  ['https://www.cannaconnection.com/strains/ak-choco-kush'],
#  ['https://www.cannaconnection.com/strains/ak-skunk-autoflowering'],
#  ['https://www.cannaconnection.com/strains/ak-widow-47'],
#  ['https://www.cannaconnection.com/strains/ak-020'],
#  ['https://www.cannaconnection.com/strains/ak-420'],
#  ['https://www.cannaconnection.com/strains/ak-420-autoflowering'],
#  ['https://www.cannaconnection.com/strains/ak-47'],
#  ['https://www.cannaconnection.com/strains/ak-48'],
#  ['https://www.cannaconnection.com/strains/ak-48-autoflowering'],
#  ['https://www.cannaconnection.com/strains/ak-og-kush'],
#  ['https://www.cannaconnection.com/strains/akorn'],
#  ['https://www.cannaconnection.com/strains/alaskan-ice'],
#  ['https://www.cannaconnection.com/strains/alchemy'],
#  ['https://www.cannaconnection.com/strains/alegria'],
#  ['https://www.cannaconnection.com/strains/allkush'],
#  ['https://www.cannaconnection.com/strains/alphadawg'],
#  ['https://www.cannaconnection.com/strains/alpujarrena'],
#  ['https://www.cannaconnection.com/strains/amazing-haze'],
#  ['https://www.cannaconnection.com/strains/amazonia'],
#  ['https://www.cannaconnection.com/strains/american-dream'],
#  ['https://www.cannaconnection.com/strains/american-kush'],
#  ['https://www.cannaconnection.com/strains/american-pie'],
#  ['https://www.cannaconnection.com/strains/amherst-sour-diesel'],
#  ['https://www.cannaconnection.com/strains/amnesi-k-lemon'],
#  ['https://www.cannaconnection.com/strains/amnesia'],
#  ['https://www.cannaconnection.com/strains/amnesia-7'],
#  ['https://www.cannaconnection.com/strains/amnesia-bilbo'],
#  ['https://www.cannaconnection.com/strains/amnesia-bilbo-autoflowering'],
#  ['https://www.cannaconnection.com/strains/amnesia-cbd'],
#  ['https://www.cannaconnection.com/strains/amnesia-gold'],
#  ['https://www.cannaconnection.com/strains/amnesia-haze'],
#  ['https://www.cannaconnection.com/strains/amnesia-haze-autoflowering'],
#  ['https://www.cannaconnection.com/strains/amnesia-haze-xl'],
#  ['https://www.cannaconnection.com/strains/amnesia-haze-xl-autoflowering'],
#  ['https://www.cannaconnection.com/strains/amnesia-kush'],
#  ['https://www.cannaconnection.com/strains/amnesia-lemon'],
#  ['https://www.cannaconnection.com/strains/amnesia-mac-ganja-amg'],
#  ['https://www.cannaconnection.com/strains/amnesia-mistery'],
#  ['https://www.cannaconnection.com/strains/amnesia-molotov'],
#  ['https://www.cannaconnection.com/strains/amnesia-ryder'],
#  ['https://www.cannaconnection.com/strains/amnesia-skunk-autoflowering'],
#  ['https://www.cannaconnection.com/strains/amnesia-white'],
#  ['https://www.cannaconnection.com/strains/amnesia-xxl-autoflowering'],
#  ['https://www.cannaconnection.com/strains/ams'],
#  ['https://www.cannaconnection.com/strains/amsterdam-mist'],
#  ['https://www.cannaconnection.com/strains/amur-giant-autoflowering'],
#  ['https://www.cannaconnection.com/strains/anesthesia'],
#  ['https://www.cannaconnection.com/strains/angel-heart'],
#  ['https://www.cannaconnection.com/strains/annapurna-superauto'],
#  ['https://www.cannaconnection.com/strains/apollo-11'],
#  ['https://www.cannaconnection.com/strains/apollo-haze'],
#  ['https://www.cannaconnection.com/strains/applejack'],
#  ['https://www.cannaconnection.com/strains/arjan-s-haze-1'],
#  ['https://www.cannaconnection.com/strains/arjan-s-ultra-haze-1'],
#  ['https://www.cannaconnection.com/strains/arjan-s-ultra-haze-2'],
#  ['https://www.cannaconnection.com/strains/arjan-s-haze-2'],
#  ['https://www.cannaconnection.com/strains/arjan-s-haze-3'],
#  ['https://www.cannaconnection.com/strains/arjan-s-strawberry-haze'],
#  ['https://www.cannaconnection.com/strains/armageddon'],
#  ['https://www.cannaconnection.com/strains/aroma'],
#  ['https://www.cannaconnection.com/strains/ash'],
#  ['https://www.cannaconnection.com/strains/atomic'],
#  ['https://www.cannaconnection.com/strains/atomical-haze'],
#  ['https://www.cannaconnection.com/strains/aurora-indica'],
#  ['https://www.cannaconnection.com/strains/auto-1'],
#  ['https://www.cannaconnection.com/strains/auto-acid'],
#  ['https://www.cannaconnection.com/strains/auto-afghan-skunk'],
#  ['https://www.cannaconnection.com/strains/auto-afghani'],
#  ['https://www.cannaconnection.com/strains/auto-alpujarrena'],
#  ['https://www.cannaconnection.com/strains/auto-anesthesia'],
#  ['https://www.cannaconnection.com/strains/auto-anubis'],
#  ['https://www.cannaconnection.com/strains/auto-bio-diesel-mass'],
#  ['https://www.cannaconnection.com/strains/auto-blackberry-kush'],
#  ['https://www.cannaconnection.com/strains/auto-blue-amnesia'],
#  ['https://www.cannaconnection.com/strains/auto-blue-diesel'],
#  ['https://www.cannaconnection.com/strains/auto-blue-pyramid'],
#  ['https://www.cannaconnection.com/strains/auto-blueberry'],
#  ['https://www.cannaconnection.com/strains/auto-blueberry-domina'],
#  ['https://www.cannaconnection.com/strains/auto-bomb'],
#  ['https://www.cannaconnection.com/strains/auto-brooklyn-sunrise'],
#  ['https://www.cannaconnection.com/strains/auto-bubblegum'],
#  ['https://www.cannaconnection.com/strains/auto-cbd-star'],
#  ['https://www.cannaconnection.com/strains/auto-cheese-nl'],
#  ['https://www.cannaconnection.com/strains/auto-chemdog'],
#  ['https://www.cannaconnection.com/strains/auto-cinderella-jack'],
#  ['https://www.cannaconnection.com/strains/auto-colorado-cookies'],
#  ['https://www.cannaconnection.com/strains/auto-critical-orange-punch'],
#  ['https://www.cannaconnection.com/strains/auto-critical-soma'],
#  ['https://www.cannaconnection.com/strains/auto-daiquiri-lime'],
#  ['https://www.cannaconnection.com/strains/auto-dark-purple'],
#  ['https://www.cannaconnection.com/strains/auto-diesel'],
#  ['https://www.cannaconnection.com/strains/auto-duck'],
#  ['https://www.cannaconnection.com/strains/auto-durban-poison'],
#  ['https://www.cannaconnection.com/strains/auto-el-fuego'],
#  ['https://www.cannaconnection.com/strains/auto-euforia'],
#  ['https://www.cannaconnection.com/strains/auto-fresh-candy'],
#  ['https://www.cannaconnection.com/strains/auto-frisian-dew'],
#  ['https://www.cannaconnection.com/strains/auto-galaxy'],
#  ['https://www.cannaconnection.com/strains/auto-glueberry-og'],
#  ['https://www.cannaconnection.com/strains/auto-jack'],
#  ['https://www.cannaconnection.com/strains/auto-jack-herer'],
#  ['https://www.cannaconnection.com/strains/auto-kaya-47'],
#  ['https://www.cannaconnection.com/strains/auto-king-kong'],
#  ['https://www.cannaconnection.com/strains/auto-kryptonite'],
#  ['https://www.cannaconnection.com/strains/auto-lavender'],
#  ['https://www.cannaconnection.com/strains/auto-lennon'],
#  ['https://www.cannaconnection.com/strains/auto-mako'],
#  ['https://www.cannaconnection.com/strains/auto-mass'],
#  ['https://www.cannaconnection.com/strains/automazar'],
#  ['https://www.cannaconnection.com/strains/auto-nefertiti'],
#  ['https://www.cannaconnection.com/strains/auto-new-york-diesel'],
#  ['https://www.cannaconnection.com/strains/auto-night-queen'],
#  ['https://www.cannaconnection.com/strains/auto-northern-lights'],
#  ['https://www.cannaconnection.com/strains/auto-og-kush'],
#  ['https://www.cannaconnection.com/strains/auto-orange-bud'],
#  ['https://www.cannaconnection.com/strains/auto-pounder'],
#  ['https://www.cannaconnection.com/strains/auto-pounder-with-cheese'],
#  ['https://www.cannaconnection.com/strains/auto-power-plant'],
#  ['https://www.cannaconnection.com/strains/auto-purple'],
#  ['https://www.cannaconnection.com/strains/auto-purple-couskush'],
#  ['https://www.cannaconnection.com/strains/auto-silver-bullet'],
#  ['https://www.cannaconnection.com/strains/auto-silver-haze'],
#  ['https://www.cannaconnection.com/strains/auto-skunk-mass'],
#  ['https://www.cannaconnection.com/strains/auto-super-hash'],
#  ['https://www.cannaconnection.com/strains/auto-super-og-kush'],
#  ['https://www.cannaconnection.com/strains/auto-tao-blueberry'],
#  ['https://www.cannaconnection.com/strains/auto-tutankhamon'],
#  ['https://www.cannaconnection.com/strains/auto-ultimate'],
#  ['https://www.cannaconnection.com/strains/auto-wappa'],
#  ['https://www.cannaconnection.com/strains/auto-white-widow'],
#  ['https://www.cannaconnection.com/strains/auto-whiteberry'],
#  ['https://www.cannaconnection.com/strains/auto-xtreme'],
#  ['https://www.cannaconnection.com/strains/auto-yumbolt'],
#  ['https://www.cannaconnection.com/strains/autoflower-haze'],
#  ['https://www.cannaconnection.com/strains/autoflowering-white-russian-1'],
#  ['https://www.cannaconnection.com/strains/automaria-ii'],
#  ['https://www.cannaconnection.com/strains/automatic'],
#  ['https://www.cannaconnection.com/strains/autopilot-xxl'],
#  ['https://www.cannaconnection.com/strains/ayahuasca-purple'],
#  ['https://www.cannaconnection.com/strains/azure-haze'],
#  ['https://www.cannaconnection.com/index.php?controller=contact'],
#  ['https://www.cannaconnection.com/blog/category/grow'],
#  ['https://www.cannaconnection.com/blog/category/articles'],
#  ['https://www.cannaconnection.com/blog/category/culture'],
#  ['https://www.cibdol.com/cbd-deals'],
#  ['https://www.zamnesia.com/zamnesia-seeds/6000-runtz-feminized.html'],
#  ['https://www.royalqueenseeds.com'],
#  ['https://www.bitcanna.io'],
#  ['https://www.facebook.com/Cannabisinfo-1324180974316509/?fref=ts'],
#  ['https://www.instagram.com/cannaconnection420/'],
#  ['https://www.cannaconnection.com/'],
#  ['https://www.cannaconnection.com/'],
#  ['https://www.cannaconnection.com/home/about-us'],
#  ['/home/privacy-policy'],
#  ['https://www.cannaconnection.com/home/cookies-policy'],
#  ['/home/terms-and-conditions'],
#  ['/sitemap'],
#  ['https://www.cannaconnection.com/home/cookies-policy'],
#  ['https://www.cannaconnection.com/'],
#  ['/strains'],
#  ['https://www.cannaconnection.com/strains'],
#  ['https://www.cannaconnection.com/strains?show_char=a'],
#  ['https://www.cannaconnection.com/strains?show_char=b'],
#  ['https://www.cannaconnection.com/strains?show_char=c'],
#  ['https://www.cannaconnection.com/strains?show_char=d'],
#  ['https://www.cannaconnection.com/strains?show_char=e'],
#  ['https://www.cannaconnection.com/strains?show_char=f'],
#  ['https://www.cannaconnection.com/strains?show_char=g'],
#  ['https://www.cannaconnection.com/strains?show_char=h'],
#  ['https://www.cannaconnection.com/strains?show_char=i'],
#  ['https://www.cannaconnection.com/strains?show_char=j'],
#  ['https://www.cannaconnection.com/strains?show_char=k'],
#  ['https://www.cannaconnection.com/strains?show_char=l'],
#  ['https://www.cannaconnection.com/strains?show_char=m'],
#  ['https://www.cannaconnection.com/strains?show_char=n'],
#  ['https://www.cannaconnection.com/strains?show_char=o'],
#  ['https://www.cannaconnection.com/strains?show_char=p'],
#  ['https://www.cannaconnection.com/strains?show_char=q'],
#  ['https://www.cannaconnection.com/strains?show_char=r'],
#  ['https://www.cannaconnection.com/strains?show_char=s'],
#  ['https://www.cannaconnection.com/strains?show_char=t'],
#  ['https://www.cannaconnection.com/strains?show_char=u'],
#  ['https://www.cannaconnection.com/strains?show_char=v'],
#  ['https://www.cannaconnection.com/strains?show_char=w'],
#  ['https://www.cannaconnection.com/strains?show_char=x'],
#  ['https://www.cannaconnection.com/strains?show_char=y'],
#  ['https://www.cannaconnection.com/strains?show_char=z'],
#  ['https://www.cannaconnection.com/strains?show_char=0-9'],
#  ['/hall-of-fame'],
#  ['/strains-top-10-lists'],
#  ['/strains/breeders'],
#  ['/grow-reports'],
#  ['/strainfinder'],
#  ['https://www.cannaconnection.com/strains/super-silver-haze'],
#  ['/blog/category/grow'],
#  ['/blog/category/grow-basics'],
#  ['/blog/category/grow-advanced'],
#  ['/blog/category/grow-troubleshooting'],
#  ['/grow-reports'],
#  ['/blog/category/grow-various'],
#  ['/blog/871-top-10-mistakes-beginning-grower'],
#  ['https://www.cannaconnection.com/blog/19222-global-cannabis-legality-and-regulation-how-is-it-managed'],
#  ['https://www.cannaconnection.com/blog/19222-global-cannabis-legality-and-regulation-how-is-it-managed'],
#  ['https://www.cannaconnection.com/blog/1913-how-to-germinate-seeds'],
#  ['https://www.cannaconnection.com/blog/1913-how-to-germinate-seeds'],
#  ['/blog/category/articles'],
#  ['/blog/category/smoking'],
#  ['/blog/category/vaping'],
#  ['/blog/category/dabbing'],
#  ['/blog/category/edibles'],
#  ['/blog/category/concentrates'],
#  ['/blog/category/reviews'],
#  ['/blog/category/use-101-various'],
#  ['https://www.cannaconnection.com/blog/8715-new-law-in-canada-legalisation-or-prohibition-2-0'],
#  ['https://www.cannaconnection.com/blog/8715-new-law-in-canada-legalisation-or-prohibition-2-0'],
#  ['https://www.cannaconnection.com/blog/18236-cannabis-gummy-bear-recipe'],
#  ['https://www.cannaconnection.com/blog/18236-cannabis-gummy-bear-recipe'],
#  ['/blog/category/culture'],
#  ['/blog/category/how-to'],
#  ['/blog/category/music-movies'],
#  ['/blog/category/reviews'],
#  ['/blog/category/marijuana-vips'],
#  ['/blog/category/organizations'],
#  ['/blog/category/various-culture'],
#  ['https://www.cannaconnection.com/stocks'],
#  ['https://www.cannaconnection.com/blog/8715-new-law-in-canada-legalisation-or-prohibition-2-0'],
#  ['https://www.cannaconnection.com/blog/8715-new-law-in-canada-legalisation-or-prohibition-2-0'],
#  ['https://www.cannaconnection.com/blog/18236-cannabis-gummy-bear-recipe'],
#  ['https://www.cannaconnection.com/blog/18236-cannabis-gummy-bear-recipe'],
#  ['/shop'],
#  ['/strains'],
#  ['/blog/category/grow'],
#  ['/blog/category/articles'],
#  ['/blog/category/culture'],
#  ['/shop'],
#  ['/strains'],
#  ['https://www.cannaconnection.com/strains'],
#  ['/hall-of-fame'],
#  ['/strains-top-10-lists'],
#  ['/strains/breeders'],
#  ['/grow-reports'],
#  ['/strainfinder'],
#  ['/blog/category/grow'],
#  ['/blog/category/grow-basics'],
#  ['/blog/category/grow-advanced'],
#  ['/blog/category/grow-troubleshooting'],
#  ['/grow-reports'],
#  ['/blog/category/grow-various'],
#  ['/blog/871-top-10-mistakes-beginning-grower'],
#  ['/blog/category/articles'],
#  ['/blog/category/smoking'],
#  ['/blog/category/vaping'],
#  ['/blog/category/dabbing'],
#  ['/blog/category/edibles'],
#  ['/blog/category/concentrates'],
#  ['/blog/category/reviews'],
#  ['/blog/category/use-101-various'],
#  ['/blog/category/culture'],
#  ['/blog/category/how-to'],
#  ['/blog/category/music-movies'],
#  ['/blog/category/reviews'],
#  ['/blog/category/marijuana-vips'],
#  ['/blog/category/organizations'],
#  ['/blog/category/various-culture'],
#  ['https://www.cannaconnection.com/stocks'],
#  ['/shop'],
#  ['https://www.cannaconnection.com/'],
#  ['https://www.facebook.com/Cannabisinfo-1324180974316509/?fref=ts'],
#  ['https://www.instagram.com/cannaconnection420/'],
#  ['https://www.cannaconnection.fr/varietes?SID=v8nat5lsreaqbb3vc79i58ev12'],
#  ['https://www.cannaconnection.es/variedades?SID=v8nat5lsreaqbb3vc79i58ev12'],
#  ['https://www.cannaconnection.de/sorten?SID=v8nat5lsreaqbb3vc79i58ev12'],
#  ['https://www.cannaconnection.it/varieta?SID=v8nat5lsreaqbb3vc79i58ev12'],
#  ['https://www.cannaconnection.com/login'],
#  ['https://www.cannaconnection.com/login?type=business'],
#  ['https://www.cannaconnection.com/home/about-us'],
#  ['https://www.cannaconnection.com/home/promote-your-shop'],
#  ['https://www.cannaconnection.com/home/advertise-with-us'],
#  ['/en/strains'],
#  ['/en/blog/category/grow'],
#  ['/en/blog/category/articles'],
#  ['/en/blog/category/culture'],
#  ['/home/privacy-policy'],
#  ['https://www.cannaconnection.com/home/cookies-policy'],
#  ['/home/terms-and-conditions'],
#  ['/sitemap'],
#  ['https://www.cannaconnection.fr/varietes?SID=v8nat5lsreaqbb3vc79i58ev12'],
#  ['https://www.cannaconnection.es/variedades?SID=v8nat5lsreaqbb3vc79i58ev12'],
#  ['https://www.cannaconnection.de/sorten?SID=v8nat5lsreaqbb3vc79i58ev12'],
#  ['https://www.cannaconnection.it/varieta?SID=v8nat5lsreaqbb3vc79i58ev12'],
#  ['https://www.cannaconnection.com/login'],
#  ['https://www.cannaconnection.com/login?type=business'],
#  ['https://www.cannaconnection.com/blog/category/grow'],
#  ['https://www.cannaconnection.com/blog/category/articles'],
#  ['https://www.cannaconnection.com/blog/category/culture'],
#  ['https://www.cibdol.com/cbd-deals'],
#  ['https://www.zamnesia.com/zamnesia-seeds/6000-runtz-feminized.html'],
#  ['https://www.royalqueenseeds.com'],
#  ['https://www.bitcanna.io'],
#  ['https://www.facebook.com/Cannabisinfo-1324180974316509/?fref=ts'],
#  ['https://www.instagram.com/cannaconnection420/'],
#  ['https://www.cannaconnection.com/'],
#  ['https://www.cannaconnection.com/strains'],
#  ['https://www.cannaconnection.com/hall-of-fame'],
#  ['https://www.cannaconnection.com/strains-top-10-lists'],
#  ['https://www.cannaconnection.com/strains/breeders'],
#  ['https://www.cannaconnection.com/strainfinder'],
#  ['https://www.cannaconnection.com/strains?show_char=a'],
#  ['https://www.cannaconnection.com/strains?show_char=b'],
#  ['https://www.cannaconnection.com/strains?show_char=c'],
#  ['https://www.cannaconnection.com/strains?show_char=d'],
#  ['https://www.cannaconnection.com/strains?show_char=e'],
#  ['https://www.cannaconnection.com/strains?show_char=f'],
#  ['https://www.cannaconnection.com/strains?show_char=g'],
#  ['https://www.cannaconnection.com/strains?show_char=h'],
#  ['https://www.cannaconnection.com/strains?show_char=i'],
#  ['https://www.cannaconnection.com/strains?show_char=j'],
#  ['https://www.cannaconnection.com/strains?show_char=k'],
#  ['https://www.cannaconnection.com/strains?show_char=l'],
#  ['https://www.cannaconnection.com/strains?show_char=m'],
#  ['https://www.cannaconnection.com/strains?show_char=n'],
#  ['https://www.cannaconnection.com/strains?show_char=o'],
#  ['https://www.cannaconnection.com/strains?show_char=p'],
#  ['https://www.cannaconnection.com/strains?show_char=q'],
#  ['https://www.cannaconnection.com/strains?show_char=r'],
#  ['https://www.cannaconnection.com/strains?show_char=s'],
#  ['https://www.cannaconnection.com/strains?show_char=t'],
#  ['https://www.cannaconnection.com/strains?show_char=u'],
#  ['https://www.cannaconnection.com/strains?show_char=v'],
#  ['https://www.cannaconnection.com/strains?show_char=w'],
#  ['https://www.cannaconnection.com/strains?show_char=x'],
#  ['https://www.cannaconnection.com/strains?show_char=y'],
#  ['https://www.cannaconnection.com/strains?show_char=z'],
#  ['https://www.cannaconnection.com/strains?show_char=0-9'],
#  ['https://www.cannaconnection.com/strains/baby-boom-auto-cbd'],
#  ['https://www.cannaconnection.com/strains/baby-boom-autoflowering'],
#  ['https://www.cannaconnection.com/strains/bad-azz-kush'],
#  ['https://www.cannaconnection.com/strains/badazz-cheese'],
#  ['https://www.cannaconnection.com/strains/baikal-express'],
#  ['https://www.cannaconnection.com/strains/banana'],
#  ['https://www.cannaconnection.com/strains/banana-kush'],
#  ['https://www.cannaconnection.com/strains/banana-split'],
#  ['https://www.cannaconnection.com/strains/bandana'],
#  ['https://www.cannaconnection.com/strains/bangi-haze'],
#  ['https://www.cannaconnection.com/strains/barbara-bud'],
#  ['https://www.cannaconnection.com/strains/bass-line'],
#  ['https://www.cannaconnection.com/strains/bc-early-blueberry'],
#  ['https://www.cannaconnection.com/strains/bc-golden-skunk'],
#  ['https://www.cannaconnection.com/strains/bc-purps'],
#  ['https://www.cannaconnection.com/strains/bcn-diesel'],
#  ['https://www.cannaconnection.com/strains/belladonna'],
#  ['https://www.cannaconnection.com/strains/berry-bomb'],
#  ['https://www.cannaconnection.com/strains/berry-bomb-autoflowering'],
#  ['https://www.cannaconnection.com/strains/berry-delight'],
#  ['https://www.cannaconnection.com/strains/berry-ryder-autoflowering'],
#  ['https://www.cannaconnection.com/strains/biddy-early'],
#  ['https://www.cannaconnection.com/strains/big-band'],
#  ['https://www.cannaconnection.com/strains/big-bang'],
#  ['https://www.cannaconnection.com/strains/big-bang-autoflowering'],
#  ['https://www.cannaconnection.com/strains/big-bomb'],
#  ['https://www.cannaconnection.com/strains/big-bomb-autoflowering'],
#  ['https://www.cannaconnection.com/strains/big-bud'],
#  ['https://www.cannaconnection.com/strains/big-bud-xxl'],
#  ['https://www.cannaconnection.com/strains/big-bud-xxl-autoflowering'],
#  ['https://www.cannaconnection.com/strains/big-buddha-cheese'],
#  ['https://www.cannaconnection.com/strains/big-buddha-cheese-autoflowering'],
#  ['https://www.cannaconnection.com/strains/big-bull'],
#  ['https://www.cannaconnection.com/strains/big-critical'],
#  ['https://www.cannaconnection.com/strains/big-devil-f1-fast-version'],
#  ['https://www.cannaconnection.com/strains/big-devil-2'],
#  ['https://www.cannaconnection.com/strains/big-devil-autoflowering'],
#  ['https://www.cannaconnection.com/strains/big-devil-xl-auto'],
#  ['https://www.cannaconnection.com/strains/big-foot'],
#  ['https://www.cannaconnection.com/strains/big-jack'],
#  ['https://www.cannaconnection.com/strains/big-kush'],
#  ['https://www.cannaconnection.com/strains/big-tooth'],
#  ['https://www.cannaconnection.com/strains/biker-kush'],
#  ['https://www.cannaconnection.com/strains/bizarre'],
#  ['https://www.cannaconnection.com/strains/black-bomb'],
#  ['https://www.cannaconnection.com/strains/black-cheese'],
#  ['https://www.cannaconnection.com/strains/black-cream-autoflowering'],
#  ['https://www.cannaconnection.com/strains/black-diesel'],
#  ['https://www.cannaconnection.com/strains/black-domina'],
#  ['https://www.cannaconnection.com/strains/black-gum'],
#  ['https://www.cannaconnection.com/strains/black-haze'],
#  ['https://www.cannaconnection.com/strains/black-jack'],
#  ['https://www.cannaconnection.com/strains/black-jack-autoflowering'],
#  ['https://www.cannaconnection.com/strains/black-jack-cbd'],
#  ['https://www.cannaconnection.com/strains/black-poison'],
#  ['https://www.cannaconnection.com/strains/black-poison-skunk'],
#  ['https://www.cannaconnection.com/strains/black-russian'],
#  ['https://www.cannaconnection.com/strains/black-widow'],
#  ['https://www.cannaconnection.com/strains/blackberry'],
#  ['https://www.cannaconnection.com/strains/blackdance'],
#  ['https://www.cannaconnection.com/strains/blackjack'],
#  ['https://www.cannaconnection.com/strains/blackwater'],
#  ['https://www.cannaconnection.com/strains/bloody-skunk-autoflowering'],
#  ['https://www.cannaconnection.com/strains/blow-mind-autoflowering'],
#  ['https://www.cannaconnection.com/strains/blue-amnesia-xxl-autoflowering'],
#  ['https://www.cannaconnection.com/strains/blue-auto-mazar'],
#  ['https://www.cannaconnection.com/strains/blue-brilliant'],
#  ['https://www.cannaconnection.com/strains/blue-cheese'],
#  ['https://www.cannaconnection.com/strains/blue-cheese-autoflowering'],
#  ['https://www.cannaconnection.com/strains/blue-critical-autoflowering'],
#  ['https://www.cannaconnection.com/strains/blue-dream'],
#  ['https://www.cannaconnection.com/strains/blue-dream-autoflowering'],
#  ['https://www.cannaconnection.com/strains/blue-dream-cbd'],
#  ['https://www.cannaconnection.com/strains/blue-dream-matic'],
#  ['https://www.cannaconnection.com/strains/blue-elite-indica'],
#  ['https://www.cannaconnection.com/strains/blue-funk'],
#  ['https://www.cannaconnection.com/strains/blue-gelato-41'],
#  ['https://www.cannaconnection.com/strains/blue-grape-dream'],
#  ['https://www.cannaconnection.com/strains/blue-hash'],
#  ['https://www.cannaconnection.com/strains/blue-haze'],
#  ['https://www.cannaconnection.com/strains/blue-kush'],
#  ['https://www.cannaconnection.com/strains/blue-kush-berry'],
#  ['https://www.cannaconnection.com/strains/blue-lemon-thai'],
#  ['https://www.cannaconnection.com/strains/blue-lemon-thai-x-aroma'],
#  ['https://www.cannaconnection.com/strains/blue-mammoth-autoflowering'],
#  ['https://www.cannaconnection.com/strains/blue-mazar'],
#  ['https://www.cannaconnection.com/strains/blue-medi-kush'],
#  ['https://www.cannaconnection.com/strains/blue-mystic'],
#  ['https://www.cannaconnection.com/strains/blue-power'],
#  ['https://www.cannaconnection.com/strains/blue-pyramid'],
#  ['https://www.cannaconnection.com/strains/blue-rhino'],
#  ['https://www.cannaconnection.com/strains/blue-spider'],
#  ['https://www.cannaconnection.com/strains/blue-widow'],
#  ['https://www.cannaconnection.com/strains/blue-zkittlez'],
#  ['https://www.cannaconnection.com/strains/blueberry'],
#  ['https://www.cannaconnection.com/strains/blueberry-autoflowering'],
#  ['https://www.cannaconnection.com/strains/blueberry-bud'],
#  ['https://www.cannaconnection.com/strains/blueberry-cheese'],
#  ['https://www.cannaconnection.com/strains/blueberry-cheese-autoflowering'],
#  ['https://www.cannaconnection.com/strains/blueberry-cheesecake'],
#  ['https://www.cannaconnection.com/strains/blueberry-cookies'],
#  ['https://www.cannaconnection.com/strains/blueberry-haze'],
#  ['https://www.cannaconnection.com/strains/blueberry-headband'],
#  ['https://www.cannaconnection.com/strains/blueberry-muffin'],
#  ['https://www.cannaconnection.com/strains/blueberry-og'],
#  ['https://www.cannaconnection.com/strains/blueberry-punch'],
#  ['https://www.cannaconnection.com/strains/blueberry-skunk'],
#  ['https://www.cannaconnection.com/strains/bona-dea-cbd'],
#  ['https://www.cannaconnection.com/strains/brainkiller-haze'],
#  ['https://www.cannaconnection.com/strains/brian-berry-cough'],
#  ['https://www.cannaconnection.com/strains/brooklyn-mango'],
#  ['https://www.cannaconnection.com/strains/brotherhood-og'],
#  ['https://www.cannaconnection.com/strains/bruce-banner-3'],
#  ['https://www.cannaconnection.com/strains/bruce-banner-bx-20'],
#  ['https://www.cannaconnection.com/strains/bubba-cheese-autoflowering'],
#  ['https://www.cannaconnection.com/strains/bubba-island-kush'],
#  ['https://www.cannaconnection.com/strains/bubba-kush'],
#  ['https://www.cannaconnection.com/strains/bubba-kush-2'],
#  ['https://www.cannaconnection.com/strains/bubba-kush-autoflowering'],
#  ['https://www.cannaconnection.com/strains/bubba-kush-cbd'],
#  ['https://www.cannaconnection.com/strains/bubba-love'],
#  ['https://www.cannaconnection.com/strains/bubba-og'],
#  ['https://www.cannaconnection.com/strains/bubba-s-gift'],
#  ['https://www.cannaconnection.com/strains/bubble-bomb'],
#  ['https://www.cannaconnection.com/strains/bubble-cheese'],
#  ['https://www.cannaconnection.com/strains/bubble-gum'],
#  ['https://www.cannaconnection.com/strains/bubble-kush'],
#  ['https://www.cannaconnection.com/strains/bubble-kush-autoflowering'],
#  ['https://www.cannaconnection.com/strains/bubble-yum'],
#  ['https://www.cannaconnection.com/strains/bubblegum-kush'],
#  ['https://www.cannaconnection.com/strains/bubblegum-xl'],
#  ['https://www.cannaconnection.com/strains/bubblegummer'],
#  ['https://www.cannaconnection.com/strains/bubblelicious'],
#  ['https://www.cannaconnection.com/strains/bubblelicious-autoflowering'],
#  ['https://www.cannaconnection.com/strains/bubblicious'],
#  ['https://www.cannaconnection.com/strains/buddha-haze'],
#  ['https://www.cannaconnection.com/strains/buddha-kush-og'],
#  ['https://www.cannaconnection.com/strains/buddha-purple-kush'],
#  ['https://www.cannaconnection.com/strains/buddha-tahoe'],
#  ['https://www.cannaconnection.com/strains/buddhas-sister'],
#  ['https://www.cannaconnection.com/strains/bullshark'],
#  ['https://www.cannaconnection.com/strains/burmese-kush'],
#  ['https://www.cannaconnection.com/strains/buzz-bomb'],
#  ['https://www.cannaconnection.com/index.php?controller=contact'],
#  ['https://www.cannaconnection.com/blog/category/grow'],
#  ['https://www.cannaconnection.com/blog/category/articles'],
#  ['https://www.cannaconnection.com/blog/category/culture'],
#  ['https://www.cibdol.com/cbd-deals'],
#  ['https://www.zamnesia.com/zamnesia-seeds/6000-runtz-feminized.html'],
#  ['https://www.royalqueenseeds.com'],
#  ['https://www.bitcanna.io'],
#  ['https://www.facebook.com/Cannabisinfo-1324180974316509/?fref=ts'],
#  ['https://www.instagram.com/cannaconnection420/'],
#  ['https://www.cannaconnection.com/'],
#  ['https://www.cannaconnection.com/'],
#  ['https://www.cannaconnection.com/home/about-us'],
#  ['/home/privacy-policy'],
#  ['https://www.cannaconnection.com/home/cookies-policy'],
#  ['/home/terms-and-conditions'],
#  ['/sitemap'],
#  ['https://www.cannaconnection.com/home/cookies-policy'],
#  ['https://www.cannaconnection.com/'],
#  ['/strains'],
#  ['https://www.cannaconnection.com/strains'],
#  ['https://www.cannaconnection.com/strains?show_char=a'],
#  ['https://www.cannaconnection.com/strains?show_char=b'],
#  ['https://www.cannaconnection.com/strains?show_char=c'],
#  ['https://www.cannaconnection.com/strains?show_char=d'],
#  ['https://www.cannaconnection.com/strains?show_char=e'],
#  ['https://www.cannaconnection.com/strains?show_char=f'],
#  ['https://www.cannaconnection.com/strains?show_char=g'],
#  ['https://www.cannaconnection.com/strains?show_char=h'],
#  ['https://www.cannaconnection.com/strains?show_char=i'],
#  ['https://www.cannaconnection.com/strains?show_char=j'],
#  ['https://www.cannaconnection.com/strains?show_char=k'],
#  ['https://www.cannaconnection.com/strains?show_char=l'],
#  ['https://www.cannaconnection.com/strains?show_char=m'],
#  ['https://www.cannaconnection.com/strains?show_char=n'],
#  ['https://www.cannaconnection.com/strains?show_char=o'],
#  ['https://www.cannaconnection.com/strains?show_char=p'],
#  ['https://www.cannaconnection.com/strains?show_char=q'],
#  ['https://www.cannaconnection.com/strains?show_char=r'],
#  ['https://www.cannaconnection.com/strains?show_char=s'],
#  ['https://www.cannaconnection.com/strains?show_char=t'],
#  ['https://www.cannaconnection.com/strains?show_char=u'],
#  ['https://www.cannaconnection.com/strains?show_char=v'],
#  ['https://www.cannaconnection.com/strains?show_char=w'],
#  ['https://www.cannaconnection.com/strains?show_char=x'],
#  ['https://www.cannaconnection.com/strains?show_char=y'],
#  ['https://www.cannaconnection.com/strains?show_char=z'],
#  ['https://www.cannaconnection.com/strains?show_char=0-9'],
#  ['/hall-of-fame'],
#  ['/strains-top-10-lists'],
#  ['/strains/breeders'],
#  ['/grow-reports'],
#  ['/strainfinder'],
#  ['https://www.cannaconnection.com/strains/super-silver-haze'],
#  ['/blog/category/grow'],
#  ['/blog/category/grow-basics'],
#  ['/blog/category/grow-advanced'],
#  ['/blog/category/grow-troubleshooting'],
#  ['/grow-reports'],
#  ['/blog/category/grow-various'],
#  ['/blog/871-top-10-mistakes-beginning-grower'],
#  ['https://www.cannaconnection.com/blog/19222-global-cannabis-legality-and-regulation-how-is-it-managed'],
#  ['https://www.cannaconnection.com/blog/19222-global-cannabis-legality-and-regulation-how-is-it-managed'],
#  ['https://www.cannaconnection.com/blog/1913-how-to-germinate-seeds'],
#  ['https://www.cannaconnection.com/blog/1913-how-to-germinate-seeds'],
#  ['/blog/category/articles'],
#  ['/blog/category/smoking'],
#  ['/blog/category/vaping'],
#  ['/blog/category/dabbing'],
#  ['/blog/category/edibles'],
#  ['/blog/category/concentrates'],
#  ['/blog/category/reviews'],
#  ['/blog/category/use-101-various'],
#  ['https://www.cannaconnection.com/blog/8715-new-law-in-canada-legalisation-or-prohibition-2-0'],
#  ['https://www.cannaconnection.com/blog/8715-new-law-in-canada-legalisation-or-prohibition-2-0'],
#  ['https://www.cannaconnection.com/blog/18236-cannabis-gummy-bear-recipe'],
#  ['https://www.cannaconnection.com/blog/18236-cannabis-gummy-bear-recipe'],
#  ['/blog/category/culture'],
#  ['/blog/category/how-to'],
#  ['/blog/category/music-movies'],
#  ['/blog/category/reviews'],
#  ['/blog/category/marijuana-vips'],
#  ['/blog/category/organizations'],
#  ['/blog/category/various-culture'],
#  ['https://www.cannaconnection.com/stocks'],
#  ['https://www.cannaconnection.com/blog/8715-new-law-in-canada-legalisation-or-prohibition-2-0'],
#  ['https://www.cannaconnection.com/blog/8715-new-law-in-canada-legalisation-or-prohibition-2-0'],
#  ['https://www.cannaconnection.com/blog/18236-cannabis-gummy-bear-recipe'],
#  ['https://www.cannaconnection.com/blog/18236-cannabis-gummy-bear-recipe'],
#  ['/shop'],
#  ['/strains'],
#  ['/blog/category/grow'],
#  ['/blog/category/articles'],
#  ['/blog/category/culture'],
#  ['/shop'],
#  ['/strains'],
#  ['https://www.cannaconnection.com/strains'],
#  ['/hall-of-fame'],
#  ['/strains-top-10-lists'],
#  ['/strains/breeders'],
#  ['/grow-reports'],
#  ['/strainfinder'],
#  ['/blog/category/grow'],
#  ['/blog/category/grow-basics'],
#  ['/blog/category/grow-advanced'],
#  ['/blog/category/grow-troubleshooting'],
#  ['/grow-reports'],
#  ['/blog/category/grow-various'],
#  ['/blog/871-top-10-mistakes-beginning-grower'],
#  ['/blog/category/articles'],
#  ['/blog/category/smoking'],
#  ['/blog/category/vaping'],
#  ['/blog/category/dabbing'],
#  ['/blog/category/edibles'],
#  ['/blog/category/concentrates'],
#  ['/blog/category/reviews'],
#  ['/blog/category/use-101-various'],
#  ['/blog/category/culture'],
#  ['/blog/category/how-to'],
#  ['/blog/category/music-movies'],
#  ['/blog/category/reviews'],
#  ['/blog/category/marijuana-vips'],
#  ['/blog/category/organizations'],
#  ['/blog/category/various-culture'],
#  ['https://www.cannaconnection.com/stocks'],
#  ['/shop'],
#  ['https://www.cannaconnection.com/'],
#  ['https://www.facebook.com/Cannabisinfo-1324180974316509/?fref=ts'],
#  ['https://www.instagram.com/cannaconnection420/'],
#  ['https://www.cannaconnection.fr/varietes?SID=gaumfb2hl21tsilmh2hhmdj0e6'],
#  ['https://www.cannaconnection.es/variedades?SID=gaumfb2hl21tsilmh2hhmdj0e6'],
#  ['https://www.cannaconnection.de/sorten?SID=gaumfb2hl21tsilmh2hhmdj0e6'],
#  ['https://www.cannaconnection.it/varieta?SID=gaumfb2hl21tsilmh2hhmdj0e6'],
#  ['https://www.cannaconnection.com/login'],
#  ['https://www.cannaconnection.com/login?type=business'],
#  ['https://www.cannaconnection.com/home/about-us'],
#  ['https://www.cannaconnection.com/home/promote-your-shop'],
#  ['https://www.cannaconnection.com/home/advertise-with-us'],
#  ['/en/strains'],
#  ['/en/blog/category/grow'],
#  ['/en/blog/category/articles'],
#  ['/en/blog/category/culture'],
#  ['/home/privacy-policy'],
#  ['https://www.cannaconnection.com/home/cookies-policy'],
#  ['/home/terms-and-conditions'],
#  ['/sitemap'],
#  ['https://www.cannaconnection.fr/varietes?SID=gaumfb2hl21tsilmh2hhmdj0e6'],
#  ['https://www.cannaconnection.es/variedades?SID=gaumfb2hl21tsilmh2hhmdj0e6'],
#  ['https://www.cannaconnection.de/sorten?SID=gaumfb2hl21tsilmh2hhmdj0e6'],
#  ['https://www.cannaconnection.it/varieta?SID=gaumfb2hl21tsilmh2hhmdj0e6'],
#  ['https://www.cannaconnection.com/login'],
#  ['https://www.cannaconnection.com/login?type=business'],
#  ['https://www.cannaconnection.com/blog/category/grow'],
#  ['https://www.cannaconnection.com/blog/category/articles'],
#  ['https://www.cannaconnection.com/blog/category/culture'],
#  ['https://www.cibdol.com/cbd-deals'],
#  ['https://www.zamnesia.com/zamnesia-seeds/6000-runtz-feminized.html'],
#  ['https://www.royalqueenseeds.com'],
#  ['https://www.bitcanna.io'],
#  ['https://www.facebook.com/Cannabisinfo-1324180974316509/?fref=ts'],
#  ['https://www.instagram.com/cannaconnection420/'],
#  ['https://www.cannaconnection.com/'],
#  ['https://www.cannaconnection.com/strains'],
#  ['https://www.cannaconnection.com/hall-of-fame'],
#  ['https://www.cannaconnection.com/strains-top-10-lists'],
#  ['https://www.cannaconnection.com/strains/breeders'],
#  ['https://www.cannaconnection.com/strainfinder'],
#  ['https://www.cannaconnection.com/strains?show_char=a'],
#  ['https://www.cannaconnection.com/strains?show_char=b'],
#  ['https://www.cannaconnection.com/strains?show_char=c'],
#  ['https://www.cannaconnection.com/strains?show_char=d'],
#  ['https://www.cannaconnection.com/strains?show_char=e'],
#  ['https://www.cannaconnection.com/strains?show_char=f'],
#  ['https://www.cannaconnection.com/strains?show_char=g'],
#  ['https://www.cannaconnection.com/strains?show_char=h'],
#  ['https://www.cannaconnection.com/strains?show_char=i'],
#  ['https://www.cannaconnection.com/strains?show_char=j'],
#  ['https://www.cannaconnection.com/strains?show_char=k'],
#  ['https://www.cannaconnection.com/strains?show_char=l'],
#  ['https://www.cannaconnection.com/strains?show_char=m'],
#  ['https://www.cannaconnection.com/strains?show_char=n'],
#  ['https://www.cannaconnection.com/strains?show_char=o'],
#  ['https://www.cannaconnection.com/strains?show_char=p'],
#  ['https://www.cannaconnection.com/strains?show_char=q'],
#  ['https://www.cannaconnection.com/strains?show_char=r'],
#  ['https://www.cannaconnection.com/strains?show_char=s'],
#  ['https://www.cannaconnection.com/strains?show_char=t'],
#  ['https://www.cannaconnection.com/strains?show_char=u'],
#  ['https://www.cannaconnection.com/strains?show_char=v'],
#  ['https://www.cannaconnection.com/strains?show_char=w'],
#  ['https://www.cannaconnection.com/strains?show_char=x'],
#  ['https://www.cannaconnection.com/strains?show_char=y'],
#  ['https://www.cannaconnection.com/strains?show_char=z'],
#  ['https://www.cannaconnection.com/strains?show_char=0-9'],
#  ['https://www.cannaconnection.com/strains/c4-autoflowering'],
#  ['https://www.cannaconnection.com/strains/c99'],
#  ['https://www.cannaconnection.com/strains/caboose'],
#  ['https://www.cannaconnection.com/strains/cal-train-wreck'],
#  ['https://www.cannaconnection.com/strains/cali-orange-bud'],
#  ['https://www.cannaconnection.com/strains/california-gold'],
#  ['https://www.cannaconnection.com/strains/california-hash-plant'],
#  ['https://www.cannaconnection.com/strains/california-indica'],
#  ['https://www.cannaconnection.com/strains/california-orange-cheese'],
#  ['https://www.cannaconnection.com/strains/californian-orange'],
#  ['https://www.cannaconnection.com/strains/californian-snow'],
#  ['https://www.cannaconnection.com/strains/canadian-kush'],
#  ['https://www.cannaconnection.com/strains/candida-cd-1'],
#  ['https://www.cannaconnection.com/strains/candy-caramelo-autoflowering'],
#  ['https://www.cannaconnection.com/strains/candy-kush'],
#  ['https://www.cannaconnection.com/strains/candy-kush-express-fast-flowering'],
#  ['https://www.cannaconnection.com/strains/candyman-haze'],
#  ['https://www.cannaconnection.com/strains/cannalope-haze'],
#  ['https://www.cannaconnection.com/strains/cannalope-kush'],
#  ['https://www.cannaconnection.com/strains/cannatonic'],
#  ['https://www.cannaconnection.com/strains/cap-peeler'],
#  ['https://www.cannaconnection.com/strains/caprichosa-thai'],
#  ['https://www.cannaconnection.com/strains/caramel-autoflowering'],
#  ['https://www.cannaconnection.com/strains/caramel-ice'],
#  ['https://www.cannaconnection.com/strains/caramella'],
#  ['https://www.cannaconnection.com/strains/caramelo'],
#  ['https://www.cannaconnection.com/strains/caribe'],
#  ['https://www.cannaconnection.com/strains/carnival'],
#  ['https://www.cannaconnection.com/strains/casey-jones'],
#  ['https://www.cannaconnection.com/strains/cash-express'],
#  ['https://www.cannaconnection.com/strains/cataract-kush'],
#  ['https://www.cannaconnection.com/strains/cbd-3d'],
#  ['https://www.cannaconnection.com/strains/cbd-auto-charlottes-angel'],
#  ['https://www.cannaconnection.com/strains/cbd-auto-compassion-lime'],
#  ['https://www.cannaconnection.com/strains/cbd-auto-white-widow'],
#  ['https://www.cannaconnection.com/strains/cbd-blue-shark'],
#  ['https://www.cannaconnection.com/strains/cbd-bomb'],
#  ['https://www.cannaconnection.com/strains/cbd-caramel'],
#  ['https://www.cannaconnection.com/strains/cbd-charlottes-angel'],
#  ['https://www.cannaconnection.com/strains/cbd-compassion'],
#  ['https://www.cannaconnection.com/strains/cbd-crack-autoflowering'],
#  ['https://www.cannaconnection.com/strains/cbd-critical-cure'],
#  ['https://www.cannaconnection.com/strains/cbd-critical-mass'],
#  ['https://www.cannaconnection.com/strains/cbd-divine'],
#  ['https://www.cannaconnection.com/strains/cbd-fix-autoflowering'],
#  ['https://www.cannaconnection.com/strains/cbd-kush'],
#  ['https://www.cannaconnection.com/strains/cbd-lemon-potion-autoflowering'],
#  ['https://www.cannaconnection.com/strains/cbd-mango-haze'],
#  ['https://www.cannaconnection.com/strains/cbd-medgom-autoflowering'],
#  ['https://www.cannaconnection.com/strains/cbd-medihaze'],
#  ['https://www.cannaconnection.com/strains/cbd-nordle'],
#  ['https://www.cannaconnection.com/strains/cbd-ph'],
#  ['https://www.cannaconnection.com/strains/cbd-shark-shock'],
#  ['https://www.cannaconnection.com/strains/cbd-skunk-haze'],
#  ['https://www.cannaconnection.com/strains/cbd-spliff-berry'],
#  ['https://www.cannaconnection.com/strains/cbd-sweet-and-sour-widow'],
#  ['https://www.cannaconnection.com/strains/cbd-therapy'],
#  ['https://www.cannaconnection.com/strains/cbd-yummy'],
#  ['https://www.cannaconnection.com/strains/cbd-chronic'],
#  ['https://www.cannaconnection.com/strains/cbd-enriched-warlock'],
#  ['https://www.cannaconnection.com/strains/ceres-kush'],
#  ['https://www.cannaconnection.com/strains/ceres-skunk'],
#  ['https://www.cannaconnection.com/strains/channel'],
#  ['https://www.cannaconnection.com/strains/chaos-kush'],
#  ['https://www.cannaconnection.com/strains/charlottes-web'],
#  ['https://www.cannaconnection.com/strains/chaze-superauto'],
#  ['https://www.cannaconnection.com/strains/cheddarhead'],
#  ['https://www.cannaconnection.com/strains/cheese'],
#  ['https://www.cannaconnection.com/strains/cheese-auto-cbd'],
#  ['https://www.cannaconnection.com/strains/cheese-autoflowering'],
#  ['https://www.cannaconnection.com/strains/cheese-cbd'],
#  ['https://www.cannaconnection.com/strains/cheese-dawg'],
#  ['https://www.cannaconnection.com/strains/cheese-n-chong'],
#  ['https://www.cannaconnection.com/strains/cheese-quake'],
#  ['https://www.cannaconnection.com/strains/cheese-xxl-autoflowering'],
#  ['https://www.cannaconnection.com/strains/cheesewreck'],
#  ['https://www.cannaconnection.com/strains/cheesus'],
#  ['https://www.cannaconnection.com/strains/cheesy-auto-cbd'],
#  ['https://www.cannaconnection.com/strains/cheesy-autoflowering'],
#  ['https://www.cannaconnection.com/strains/cheesy-dick'],
#  ['https://www.cannaconnection.com/strains/cheesy-rider'],
#  ['https://www.cannaconnection.com/strains/chem-4-og'],
#  ['https://www.cannaconnection.com/strains/chem-berry-d'],
#  ['https://www.cannaconnection.com/strains/chem-beyond-diesel-cbd'],
#  ['https://www.cannaconnection.com/strains/chemdawg'],
#  ['https://www.cannaconnection.com/strains/chem-valley-kush'],
#  ['https://www.cannaconnection.com/strains/chemdog'],
#  ['https://www.cannaconnection.com/strains/chemdog-millionaire'],
#  ['https://www.cannaconnection.com/strains/chemmy-jones'],
#  ['https://www.cannaconnection.com/strains/chernobyl'],
#  ['https://www.cannaconnection.com/strains/cherry-bomb'],
#  ['https://www.cannaconnection.com/strains/cherry-bomb-autoflowering'],
#  ['https://www.cannaconnection.com/strains/cherry-bud-autoflowering'],
#  ['https://www.cannaconnection.com/strains/cherry-cordial'],
#  ['https://www.cannaconnection.com/strains/cherry-malawi'],
#  ['https://www.cannaconnection.com/strains/cherrygasm'],
#  ['https://www.cannaconnection.com/strains/chicle'],
#  ['https://www.cannaconnection.com/strains/chiesel'],
#  ['https://www.cannaconnection.com/strains/chiesel-autoflowering'],
#  ['https://www.cannaconnection.com/strains/china-yunnan'],
#  ['https://www.cannaconnection.com/strains/choco-bud'],
#  ['https://www.cannaconnection.com/strains/choco-candy'],
#  ['https://www.cannaconnection.com/strains/choco-haze'],
#  ['https://www.cannaconnection.com/strains/choco-kush-autoflowering'],
#  ['https://www.cannaconnection.com/strains/chocolate-chunk'],
#  ['https://www.cannaconnection.com/strains/chocolate-fondue'],
#  ['https://www.cannaconnection.com/strains/chocolate-mint-og'],
#  ['https://www.cannaconnection.com/strains/chocolope'],
#  ['https://www.cannaconnection.com/strains/chocolope-kush'],
#  ['https://www.cannaconnection.com/strains/chronic'],
#  ['https://www.cannaconnection.com/strains/chronic-lights'],
#  ['https://www.cannaconnection.com/strains/chronic-ryder'],
#  ['https://www.cannaconnection.com/strains/chronic-thunder'],
#  ['https://www.cannaconnection.com/strains/chunky-cheeze'],
#  ['https://www.cannaconnection.com/strains/cinderella-99'],
#  ['https://www.cannaconnection.com/strains/citral-skunk'],
#  ['https://www.cannaconnection.com/strains/citrus-smoothie'],
#  ['https://www.cannaconnection.com/strains/claustrum'],
#  ['https://www.cannaconnection.com/strains/climax-autoflowering'],
#  ['https://www.cannaconnection.com/strains/cluster-bomb'],
#  ['https://www.cannaconnection.com/strains/cobra-autoflowering'],
#  ['https://www.cannaconnection.com/strains/cocoa-kush'],
#  ['https://www.cannaconnection.com/strains/cole-train'],
#  ['https://www.cannaconnection.com/strains/colombian'],
#  ['https://www.cannaconnection.com/strains/colombian-sweet'],
#  ['https://www.cannaconnection.com/strains/coma-cluster'],
#  ['https://www.cannaconnection.com/strains/confidencial-medicine'],
#  ['https://www.cannaconnection.com/strains/confidencial-og'],
#  ['https://www.cannaconnection.com/strains/congo'],
#  ['https://www.cannaconnection.com/strains/congo-haze'],
#  ['https://www.cannaconnection.com/strains/conspiracy-kush'],
#  ['https://www.cannaconnection.com/strains/cookies-and-cream-cheese'],
#  ['https://www.cannaconnection.com/strains/cookies-haze'],
#  ...]
